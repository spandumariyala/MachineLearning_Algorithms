# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns 
import os

# %%
file = pd.read_csv(r'C:\Users\naveen\Desktop\EDA_HR_DATA\New folder\Advertising.csv')

# %%
file
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# ...

# %%
file_drop = file.drop('Unnamed: 0',axis=1)

# %%
file_drop
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# 5      8.7   48.9       75.0    7.2
# 6     57.5   32.8       23.5   11.8
# 7    120.2   19.6       11.6   13.2
# 8      8.6    2.1        1.0    4.8
# 9    199.8    2.6       21.2   10.6
# 10    66.1    5.8       24.2    8.6
# 11   214.7   24.0        4.0   17.4
# 12    23.8   35.1       65.9    9.2
# 13    97.5    7.6        7.2    9.7
# 14   204.1   32.9       46.0   19.0
# 15   195.4   47.7       52.9   22.4
# 16    67.8   36.6      114.0   12.5
# 17   281.4   39.6       55.8   24.4
# 18    69.2   20.5       18.3   11.3
# 19   147.3   23.9       19.1   14.6
# 20   218.4   27.7       53.4   18.0
# 21   237.4    5.1       23.5   12.5
# 22    13.2   15.9       49.6    5.6
# 23   228.3   16.9       26.2   15.5
# 24    62.3   12.6       18.3    9.7
# ...

# %%
file_drop.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
np.corrcoef(file_drop)
# Out:
# array([[ 1.        ,  0.5429125 , -0.25741671, ...,  0.97209458,
#          0.99763425,  0.97550501],
#        [ 0.5429125 ,  1.        ,  0.62929429, ...,  0.36360401,
#          0.50068397,  0.37276727],
#        [-0.25741671,  0.62929429,  1.        , ..., -0.46924202,
#         -0.3164027 , -0.45799056],
#        ...,
#        [ 0.97209458,  0.36360401, -0.46924202, ...,  1.        ,
#          0.98561106,  0.99986547],
#        [ 0.99763425,  0.50068397, -0.3164027 , ...,  0.98561106,
#          1.        ,  0.9879358 ],
#        [ 0.97550501,  0.37276727, -0.45799056, ...,  0.99986547,
#          0.9879358 ,  1.        ]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
feature_cols = ['TV']
X = file[feature_cols]
Y = file.sales

#using stats model
import statsmodels.api as sm

from sklearn.model_selection import train_test_split
X_train,x_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2,random_state = 0)


model2 = sm.OLS(Y,X).fit()
print(model2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     1733.
# Date:                Thu, 11 Jul 2019   Prob (F-statistic):          3.52e-100
# Time:                        11:52:52   Log-Likelihood:                -597.51
# No. Observations:                 200   AIC:                             1197.
# Df Residuals:                     199   BIC:                             1200.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# TV             0.0832      0.002     41.633      0.000       0.079       0.087
# ...

# %%
feature_cols = ['TV','radio']
X1 = file[feature_cols]
Y1 = file.sales


from sklearn.linear_model import LinearRegression

lm = LinearRegression()
lm.fit(X1,Y1)

model2 = sm.OLS(Y1,X1).fit()
print(model3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                     5206.
# Date:                Thu, 11 Jul 2019   Prob (F-statistic):          6.73e-172
# Time:                        12:05:15   Log-Likelihood:                -426.71
# No. Observations:                 200   AIC:                             857.4
# Df Residuals:                     198   BIC:                             864.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# TV             0.0548      0.001     42.962      0.000       0.052       0.057
# ...

# %%
feature_cols = ['TV','radio','newspaper']
X2 = file[feature_cols]
Y2 = file.sales


from sklearn.linear_model import LinearRegression

lm = LinearRegression()
lm.fit(X2,Y2)


model4 = sm.OLS(Y2,X2).fit()
print(model4.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.982
# Method:                 Least Squares   F-statistic:                     3566.
# Date:                Thu, 11 Jul 2019   Prob (F-statistic):          2.43e-171
# Time:                        12:05:16   Log-Likelihood:                -423.54
# No. Observations:                 200   AIC:                             853.1
# Df Residuals:                     197   BIC:                             863.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# TV             0.0538      0.001     40.507      0.000       0.051       0.056
# ...

# %%
evaluation_metrics = ['AIC','BIC','Rsquare',"AdjRsquare",'RMSE']
model2_metrics=list([model2.aic,model2.bic,model2.rsquared,model2.rsquared_adj,model2.mse_resid])
model3_metrics=list([model3.aic,model3.bic,model3.rsquared,model3.rsquared_adj,model3.mse_resid])
model4_metrics=list([model4.aic,model4.bic,model4.rsquared,model4.rsquared_adj,model4.mse_resid])

data = pd.DataFrame(zip(evaluation_metrics,model2_metrics,model3_metrics,model4_metrics))
data.columns=['Metrics','tv','Tv-Radio','Tv-Radio-Newspaper']
data
# Out:
#       Metrics          tv    Tv-Radio  Tv-Radio-Newspaper
# 0         AIC  857.412918  857.412918          853.082357
# 1         BIC  864.009553  864.009553          862.977309
# 2     Rsquare    0.981337    0.981337            0.981918
# 3  AdjRsquare    0.981148    0.981148            0.981643
# 4        RMSE    4.217480    4.217480            4.106817

# %%
pd.DataFrame(model2.params)
# Out:
#               0
# const  7.032594
# TV     0.047537

# %%
model2.aic
# Out:
# 857.412918290054

# %%
model2.rsquared
# Out:
# 0.9813366016893854

# %%
import lmdiag
plt.figure(figsize=(12,10))
lmdiag.plot(model3);

# %%
0.04422*135+0.195295*43+3.051908
# Out:
# 17.419293
